# %% [markdown]
# ## Conditional Expression

# %%
if 10 > 10:
    print(True)
elif 10 > 11:
    print("Hello")
else:
    print(False)

if int(input("How tall are you in cm?")) > 180:
    print("You are over 180")
else:
    print("You are less than 180")
# Out:
# False
# You are less than 180

# %% [markdown]
# ## Multiple If Conditional Expression

# %%
my_money = 15
if my_money > 0:
    print(f"My money, {my_money} is greater than 0")

    if my_money > 10:
        print(f"My money, {my_money} is also greater than 10")

    if my_money > 20:
        print(f"My money, {my_money} is also greater than 20")
    else:
        print(f"My money, {my_money} is less than equal to 20")
# Out:
# My money, 15 is greater than 0
# My money, 15 is also greater than 10
# My money, 15 is less than equal to 20

# %% [markdown]
# ## Logical Operator

# %%
# Logical Operators
# A and B : Both should be True
# X or Y : One of them is True
# not E : The opposite value True <-> False

value = 3
if isinstance(value, int) or value > 5:
    print("Correct")
else:
    print("Not correct")


if not isinstance(value, float):
    print(f"{value} is not float")
# Out:
# Correct
# 3 is not float

# %% [markdown]
# ## Randomization module

# %%
# random module
import random

print(random.randint(1, 100)) # both included

random_float = random.random() # 0 - 1
print(random_float)

# # how to generate 0 - 10???
print(int(random_float * 10))
# Out:
# 79
# 0.20574833939875248
# 2

# %% [markdown]
# ## Practice

# %%
import random

random_int = random.randint(0, 1)

if random_int == 0:
    print("Head")
else:
    print("Tail")
# Out:
# Head
